# %% [markdown]
# # A binary descriptor for medicine research
#
# ![molecule_1.png](attachment:molecule_1.png)

# %% [markdown]
# ## Problem description:
# -  Drug discovery
# -  Human proteins need to react with molecules
# -  If reaction between molecule and protein is high ➡ good candiate for Medicine

# %% [markdown]
# ## Dataset:
# -  Put together by an Machine learning Youtuber [1]
# -  Collected from the Chembl database [2]
# -  Bioactivity < 6 inactive, Bioactivity > 6 active ➡ Binary Classifier
# ![Selection_074.png](attachment:Selection_074.png)

# %% [markdown]
# ## Facts:
# -  8.3 Mb of Data
# -  71973 Molecules
#
# ## Filtering: Values are experimental results from laboratories
# -  missing pchembl_values
# -  Elimination of multiple occurences of molecules
# -  ~7549 missing or not accurate pchembl_values
# -  ~1000 double molecules
# -  ~1000 molecules that do not target beta-lactamase
#
# ## Resulting Dataset: 61740 molecules

# %% [markdown]
# ## Descriptors
# -  1600 2D & 3D Descriptor in 50 classes
# -  3D descriptors often return nans ➡ eliminated
# -  ~1000 2D Descriptors can be calculated
# -  Due to nans I used 611 in the end

# %% [markdown]
# ## Descriptors
# - Either float or int and two columns with boolean
# - Sparse & high value differences
# - integer descriptors could be interpreted as classes ➡ Todo
#
# ![Selection_075.png](attachment:Selection_075.png)

# %% [markdown]
# ## What was implemented:
# ### PCA ➡ Fear of to long training time
# ### Random Forest acc about 80%
# ### MLPC Classifier acc about 73%
# ### But with a big caveat

# %% [markdown]
# ## Problems with the classification
# ### Highly inbalanced dataset ➡ models mainly predict 'inactive'
#
# ![Confusion_matrix_MLP_normalized.png](attachment:Confusion_matrix_MLP_normalized.png)

# %% [markdown]
# ![RF_Confusion_matrix_normalized.png](attachment:RF_Confusion_matrix_normalized.png)

# %% [markdown]
# # Learnings from the project
# ## Dataset preparation takes a long time
# ## Data is crucial to understand
# ## More investment into more complex models
